# %%
        #   0        1.       2.      3.          4.     5
lista = ["alb", "verde", "negru", "rosu", "albastru", "mov"]

# %%
lista[0]
# Out:
# 'alb'

# %%
len(lista)
# Out:
# 6

# %%
            # cheie : valoare,
dictionar = { "lapte" : "alb",
              "iarba" :  "verde", 
              "cafea" : "negru", 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov"}

# %%
len(dictionar)
# Out:
# 6

# %%
dictionar["lapte"]
# Out:
# 'alb'

# %%
dictionar["alb"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dictionar["alb"]
#
# KeyError: 'alb'

# %%
dictionar.keys()
# Out:
# dict_keys(['lapte', 'iarba', 'cafea', 'sange', 'cer', 'cravata'])

# %%
dictionar.values()
# Out:
# dict_values(['alb', 'verde', 'negru', 'rosu', 'albastru', 'mov'])

# %%
            # cheie : valoare,
dictionar = { "lapte" : "alb",
              "iarba" :  "verde", 
              "cafea" : "negru", 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov"}

# %%
for i in dictionar:
    print("i=", i)
# Out:
# i= lapte
# i= iarba
# i= cafea
# i= sange
# i= cer
# i= cravata

# %%
for cheie in dictionar:
    print("valoare=", dictionar[cheie])
# Out:
# valoare= alb
# valoare= verde
# valoare= negru
# valoare= rosu
# valoare= albastru
# valoare= mov

# %% [markdown]
# # Dictionarul este mutabil

# %%
dictionar = { "lapte" : "alb",
              "iarba" :  "verde", 
              "cafea" : "negru", 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov"}

# %%
# INSERARE
dictionar["apa"] = "transparent"

# %%
dictionar
# Out:
# {'lapte': 'alb',
#  'iarba': 'verde',
#  'cafea': 'negru',
#  'sange': 'rosu',
#  'cer': 'albastru',
#  'cravata': 'mov',
#  'apa': 'transparent'}

# %%
# CITIRE
dictionar["sange"]
# Out:
# 'rosu'

# %%
# UPDATE
dictionar["cer"] = "gri"
dictionar
# Out:
# {'lapte': 'alb',
#  'iarba': 'verde',
#  'cafea': 'negru',
#  'sange': 'rosu',
#  'cer': 'gri',
#  'cravata': 'mov',
#  'apa': 'transparent'}

# %%
dictionar["mobila"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dictionar["mobila"]
#
# KeyError: 'mobila'

# %%
print(dictionar.get("mobila"))
# Out:
# None

# %%
x = None
print(x, type(x))
# Out:
# None <class 'NoneType'>

# %%
dictionar.get("mobila", 333)
# Out:
# 333

# %%
dictionar.get("cer", 333)
# Out:
# 'gri'

# %%
dictionar = { "lapte" : 200,
              "iarba" :  "verde", 
              "cafea" : ["negru", "alb"], 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov"}
print(dictionar)
# Out:
# {'lapte': 200, 'iarba': 'verde', 'cafea': ['negru', 'alb'], 'sange': 'rosu', 'cer': 'albastru', 'cravata': 'mov'}

# %%
dictionar = { "lapte" : 200,
              "iarba" :  "verde", 
              "cafea" : ["negru", "alb"], 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov",
             300: 500}
print(dictionar)
# Out:
# {'lapte': 200, 'iarba': 'verde', 'cafea': ['negru', 'alb'], 'sange': 'rosu', 'cer': 'albastru', 'cravata': 'mov', 300: 500}

# %%
dictionar[300]
# Out:
# 500

# %% [markdown]
# # Cheile trebuie sa fie imutabile

# %%
dictionar = { "lapte" : 200,
              "iarba" :  "verde", 
              "cafea" : ["negru", "alb"], 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov",
             (300, 200): 500}
print(dictionar)
# Out:
# {'lapte': 200, 'iarba': 'verde', 'cafea': ['negru', 'alb'], 'sange': 'rosu', 'cer': 'albastru', 'cravata': 'mov', (300, 200): 500}

# %%
dictionar = { "lapte" : 200,
              "iarba" :  "verde", 
              "cafea" : ["negru", "alb"], 
              "sange" :  "rosu", 
                "cer" : "albastru", 
             "cravata": "mov",
             [300, 200]: 500}
print(dictionar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dictionar = { "lapte" : 200,
#       2               "iarba" :  "verde",
#       3               "cafea" : ["negru", "alb"],
#       4               "sange" :  "rosu",
#       5                 "cer" : "albastru",
#       6              "cravata": "mov",
#       7              [300, 200]: 500}
#       8 print(dictionar)
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
            # inaltime, temperatura, grutate, 
masuratori = [170, 22, 85, 38]


masuratori = {
    "inaltime" : 170,
    "greutate" : 85
}

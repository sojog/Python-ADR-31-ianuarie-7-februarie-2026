# %%
x = "buna ziua"

# %%
len(x)
# Out:
# 9

# %%
x.upper()
# Out:
# 'BUNA ZIUA'

# %%
x.title()
# Out:
# 'Buna Ziua'

# %%
x.capitalize()
# Out:
# 'Buna ziua'

# %%
x = "BUNA SEARA"
x.lower()
# Out:
# 'buna seara'

# %%
x = "123"
x.isalnum()
# Out:
# True

# %%
x = "123das"
x.isalnum()
# Out:
# True

# %%
x = "123das*"
x.isalnum()
# Out:
# False

# %%
x = "123das "
x.isalnum()
# Out:
# False

# %%
x = "123das"
x.isnumeric()
# Out:
# False

# %%
x = "123"
x.isnumeric()
# Out:
# True

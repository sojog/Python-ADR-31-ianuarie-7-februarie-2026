# %%
def adunare(a, b):
    return a + b

# %%
adunare(2, 2)
# Out:
# 4

# %%
adunare(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 adunare(2)
#
# TypeError: adunare() missing 1 required positional argument: 'b'

# %%
adunare(2, 3, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 adunare(2, 3, 4)
#
# TypeError: adunare() takes 2 positional arguments but 3 were given

# %%
def suma(*numere):
    print(numere, type(numere))

# %%
suma(10, 20, 30)
# Out:
# (10, 20, 30) <class 'tuple'>

# %%
def suma(*numere):
    print(numere, type(numere))
    total = 0
    for val in numere:
        total += val
    return total

# %%
suma(10, 20, 30)
# Out:
# (10, 20, 30) <class 'tuple'>
# 60

# %%
def suma(*args):
    total = 0
    for val in args:
        total += val
    return total

# %%
def functie_cu_parametri_optionali ( *args, **kargs):
    print(args, type(args))
    print(kargs, type(kargs))

# %%
functie_cu_parametri_optionali(1, 2, 3)
# Out:
# (1, 2, 3) <class 'tuple'>
# {} <class 'dict'>

# %%
functie_cu_parametri_optionali(1, 2, 3, cheie = "valoare", cheie2 = "valoare2")
# Out:
# (1, 2, 3) <class 'tuple'>
# {'cheie': 'valoare', 'cheie2': 'valoare2'} <class 'dict'>

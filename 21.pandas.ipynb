# %% [markdown]
# # # Instalare pandas cu comanda: pip install pandas

# %%
import pandas as pd

# %%
pd.read_csv("fisier_csv.csv")
# Out:
#         cer  iarba   soare
# 0  albastru  verde  galben
# 1  albastru  verde  galben
# 2  albastru  verde  galben
# 3  albastru  verde  galben
# 4  albastru  verde  galben

# %%
dictionar = {
    "cer" : "albastru",
    "iarba" : "verde",
    "soare" : "galben"
}


pd.DataFrame([dictionar])
# Out:
#         cer  iarba   soare
# 0  albastru  verde  galben

# %%
dictionar1 = {
    "cer" : "albastru",
    "iarba" : "verde",
    "soare" : "galben"
}

dictionar2 = {
    "cer" : "gri",
    "iarba" : "maro",
    "soare" : "portocaliu"
}

df = pd.DataFrame([dictionar1, dictionar2])
df
# Out:
#         cer  iarba       soare
# 0  albastru  verde      galben
# 1       gri   maro  portocaliu

# %%
df[["cer"]]
# Out:
#         cer
# 0  albastru
# 1       gri

# %%
df[["cer", "iarba"]]
# Out:
#         cer  iarba
# 0  albastru  verde
# 1       gri   maro

# %%
df.iloc[0]
# Out:
# cer      albastru
# iarba       verde
# soare      galben
# Name: 0, dtype: object

# %%
df[ df["iarba"] == "verde" ]
# Out:
#         cer  iarba   soare
# 0  albastru  verde  galben

# %%
df.to_excel("fisier_excel.xlsx")

# %%
pd.read_excel("fisier_excel.xlsx", index_col=0)
# Out:
#         cer  iarba       soare
# 0  albastru  verde      galben
# 1       gri   maro  portocaliu

# %%
df.to_numpy()
# Out:
# array([['albastru', 'verde', 'galben'],
#        ['gri', 'maro', 'portocaliu']], dtype=object)

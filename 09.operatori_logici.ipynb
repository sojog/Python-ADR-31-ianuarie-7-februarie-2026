# %% [markdown]
# Operatori binari : AND si OR

# %% [markdown]
# # AND - True daca ambele sunt True

# %%
print("True and True = ", True and True ) 
print("False and True = ", False and True ) 
print("True and False = ", True and False ) 
print("False and False = ", False and False )
# Out:
# True and True =  True
# False and True =  False
# True and False =  False
# False and False =  False

# %% [markdown]
# # OR  - True daca cel putin una este True

# %%
print("True or True = ", True or True ) 
print("False or True = ", False or True ) 
print("True or False = ", True or False ) 
print("False or False = ", False or False )
# Out:
# True or True =  True
# False or True =  True
# True or False =  True
# False or False =  False

# %% [markdown]
# Operator unar -> NOT

# %%
print("not True = ", not True)
print("not False = ", not False)
# Out:
# not True =  False
# not False =  True

# %%
not not False
# Out:
# False

# %%
not not not not False
# Out:
# False

# %% [markdown]
# # Operatorii logici pot fi apelati si pe alte tipuri de date decat boolean

# %%
not 10
# Out:
# False

# %%
not "hello"
# Out:
# False

# %%
10 and 20
# Out:
# 20

# %%
0 and 20
# Out:
# 0

# %%
10 or 20
# Out:
# 10

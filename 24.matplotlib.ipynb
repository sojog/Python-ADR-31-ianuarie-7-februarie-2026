# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(2, 3)

# %%
plt.scatter([2, 4], [3, 5])

# %%
plt.scatter([2, 4, 7], [3, 5, 17])

# %%
plt.plot([2, 4, 7], [3, 5, 17])

# %%
plt.scatter([2, 4, 7], [3, 5, 17])
plt.plot([2, 4, 7], [3, 5, 17])

# %%
plt.bar([2, 4, 7], [3, 5, 17])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([2, 4, 7], [3, 5, 17])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([2, 4, 7], [3, 5, 17])
plt.show()

# %%
plt.pie([25, 25, 50]);

# %%
plt.pie([25, 25, 50], labels=["cartofi", "carne", "legume"]);

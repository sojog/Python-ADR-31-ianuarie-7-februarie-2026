# %%
20 * 3
# Out:
# 60

# %%
print(20 * 3)
# Out:
# 60

# %% [markdown]
# Cele 4 tipuri de date de baza (primitive)

# %% [markdown]
# # 1. Int (integer)

# %%
x = 20
print(x)
# Out:
# 20

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
type(x)
# Out:
# int

# %% [markdown]
# # 2. Float (floating point)

# %%
x = 20.321

# %%
# Variabilele trebuie sa fie definite si initializate in acelasi timp
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Variabilele trebuie sa fie definite si initializate in acelasi timp
# ----> 2 y
#
# NameError: name 'y' is not defined

# %%
x = 20.321
print(type(x))
# Out:
# <class 'float'>

# %%
3 + 5.0
# Out:
# 8.0

# %% [markdown]
# # 3. Str (string - textul)

# %%
x = "321"
x
# Out:
# '321'

# %%
print(x)
# Out:
# 321

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = "salutare"
print(x)
# Out:
# salutare

# %% [markdown]
# # 4. Bool. - (boolean - True sau False)

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = False
print(type(x))
# Out:
# <class 'bool'>

# %%
x = True 
x + 3
# Out:
# 4

# %%
x = True 
x + 3.4
# Out:
# 4.4

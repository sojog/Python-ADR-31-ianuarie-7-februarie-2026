# %%
lista = [20, 30, 40]
print(lista)
# Out:
# [20, 30, 40]

# %%
print(type(lista))
# Out:
# <class 'list'>

# %%
lista = [20, 30, 40, 32.032, True, "hello"]
print(lista)
# Out:
# [20, 30, 40, 32.032, True, 'hello']

# %%
lista = [20, 30, 40, 32.032, True, "hello", [32, 321, 312]]
print(lista)
# Out:
# [20, 30, 40, 32.032, True, 'hello', [32, 321, 312]]

# %%
lista = [20, 30, 40, 32.032, True, "hello", [32, 321, 312]]
print(len(lista))
# Out:
# 7

# %%
        # 0, 1,  2,      3,    4,      5,              6 
lista = [20, 30, 40, 32.032, True, "hello", [32, 321, 312]]
lista[0]
# Out:
# 20

# %%
lista[2]
# Out:
# 40

# %%
lista[6]
# Out:
# [32, 321, 312]

# %%
lista[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 lista[7]
#
# IndexError: list index out of range

# %%
        # 0, 1,  2,      3,    4,      5,               6 
        # -7, -6, -5,     -4,   -3,      -2,           -1
lista = [20, 30, 40, 32.032, True, "hello", [32, 321, 312]]

lista[-1]
# Out:
# [32, 321, 312]

# %%
lista[len(lista) - 1]
# Out:
# [32, 321, 312]

# %%
lista[6]
# Out:
# [32, 321, 312]

# %%
lista = [20, 30, 40, 32.032, True, "hello", [32, 321, 312]]

lista.append(20)
print(lista)
# Out:
# [20, 30, 40, 32.032, True, 'hello', [32, 321, 312], 20]

# %%
lista.append("world")
print(lista)
# Out:
# [20, 30, 40, 32.032, True, 'hello', [32, 321, 312], 20, 'world']

# %%
lista.insert(1, "hello")
print(lista)
# Out:
# [20, 'hello', 30, 40, 32.032, True, 'hello', [32, 321, 312], 20, 'world']

# %%
lista.pop()
print(lista)
# Out:
# [20, 'hello', 30, 40, 32.032, True, 'hello', [32, 321, 312], 20]

# %%
lista.pop(1)
print(lista)
# Out:
# [20, 30, 40, 32.032, True, 'hello', [32, 321, 312], 20]

# %%
lista.clear()
print(lista)
# Out:
# []

# %%
lista = [20, 'hello', 30, 40, 32.032, True, 'hello', [32, 321, 312], 20]


for i in lista:
    print("i=", i)
# Out:
# i= 20
# i= hello
# i= 30
# i= 40
# i= 32.032
# i= True
# i= hello
# i= [32, 321, 312]
# i= 20

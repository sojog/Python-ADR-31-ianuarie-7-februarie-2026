# %%
print("alb", "rosu", "verde")
# Out:
# alb rosu verde

# %%
x = 10
y = x
print(y)
# Out:
# 10

# %%
f = print
f
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
f("alb", "rosu", "verde")
# Out:
# alb rosu verde

# %%
def adunare(a, b):
    return a + b

# %%
def scadere(a, b):
    return a - b

# %%
def inmultire(a, b):
    return a * b

# %%
def executa_operatia(functia, a, b):
    return functia(a, b)

# %%
executa_operatia(inmultire, 2, 3)
# Out:
# 6

# %%
executa_operatia(scadere, 200, 300)
# Out:
# -100

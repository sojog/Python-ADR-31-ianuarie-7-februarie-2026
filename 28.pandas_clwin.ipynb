# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv("https://raw.githubusercontent.com/sojog/Python-ADR-31-ianuarie-7-februarie-2026/refs/heads/main/clwin.csv")
# Out:
#     id      country           team  trophies
# 0    0      England      Liverpool       6.0
# 1    1        Spain      Barcelona       5.0
# 2    2      England     Man United       3.0
# 3    3        Italy          Inter       3.0
# 4    4      England        Chelsea       2.0
# 5    5      England        Chelsea       2.0
# 6    6      England   Nottm Forest       2.0
# 7    7     Portugal        Benfica       2.0
# 8    8        Italy       Juventus       2.0
# 9    9     Portugal       FC Porto       2.0
# 10  10      England       Man City       1.0
# 11  11      Germany       Dortmund       1.0
# 12  12  Netherlands      Feyenoord       1.0
# 13  13       France      Marseille       1.0
# 14  14      England    Aston Villa       1.0
# 15  15      Germany        Hamburg       1.0
# 16  16       Serbia  Crvena zvezda       1.0
# 17  17      Romania           FCSB       NaN
# 18  18  Netherlands            PSV       1.0
# 19  19     Scotland         Celtic       1.0

# %%
pd.read_csv("date/clwin.csv")
# Out:
#     id      country           team  trophies
# 0    0      England      Liverpool       6.0
# 1    1        Spain      Barcelona       5.0
# 2    2      England     Man United       3.0
# 3    3        Italy          Inter       3.0
# 4    4      England        Chelsea       2.0
# 5    5      England        Chelsea       2.0
# 6    6      England   Nottm Forest       2.0
# 7    7     Portugal        Benfica       2.0
# 8    8        Italy       Juventus       2.0
# 9    9     Portugal       FC Porto       2.0
# 10  10      England       Man City       1.0
# 11  11      Germany       Dortmund       1.0
# 12  12  Netherlands      Feyenoord       1.0
# 13  13       France      Marseille       1.0
# 14  14      England    Aston Villa       1.0
# 15  15      Germany        Hamburg       1.0
# 16  16       Serbia  Crvena zvezda       1.0
# 17  17      Romania           FCSB       NaN
# 18  18  Netherlands            PSV       1.0
# 19  19     Scotland         Celtic       1.0

# %%
df = pd.read_csv("date/clwin.csv", index_col="id")
df
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool       6.0
# 1         Spain      Barcelona       5.0
# 2       England     Man United       3.0
# 3         Italy          Inter       3.0
# 4       England        Chelsea       2.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      England       Man City       1.0
# 11      Germany       Dortmund       1.0
# 12  Netherlands      Feyenoord       1.0
# 13       France      Marseille       1.0
# 14      England    Aston Villa       1.0
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %%
df.describe()
# Out:
#         trophies
# count  19.000000
# mean    2.000000
# std     1.414214
# min     1.000000
# 25%     1.000000
# 50%     2.000000
# 75%     2.000000
# max     6.000000

# %% [markdown]
# # 1. Filtrare coloane (selectare a 2 dintre ele)

# %%
df.keys()
# Out:
# Index(['country', 'team', 'trophies'], dtype='object')

# %%
df [ [ 'team', 'trophies'] ]
# Out:
#              team  trophies
# id
# 0       Liverpool       6.0
# 1       Barcelona       5.0
# 2      Man United       3.0
# 3           Inter       3.0
# 4         Chelsea       2.0
# 5         Chelsea       2.0
# 6    Nottm Forest       2.0
# 7         Benfica       2.0
# 8        Juventus       2.0
# 9        FC Porto       2.0
# 10       Man City       1.0
# 11       Dortmund       1.0
# 12      Feyenoord       1.0
# 13      Marseille       1.0
# 14    Aston Villa       1.0
# 15        Hamburg       1.0
# 16  Crvena zvezda       1.0
# 17           FCSB       NaN
# 18            PSV       1.0
# 19         Celtic       1.0

# %% [markdown]
# # 2. Filtrare dupa index

# %%
df.iloc[9]
# Out:
# country     Portugal
# team        FC Porto
# trophies         2.0
# Name: 9, dtype: object

# %%
    # inclus: neinclus
df.iloc[ 10 :    16] # slice ->
# Out:
#         country         team  trophies
# id
# 10      England     Man City       1.0
# 11      Germany     Dortmund       1.0
# 12  Netherlands    Feyenoord       1.0
# 13       France    Marseille       1.0
# 14      England  Aston Villa       1.0
# 15      Germany      Hamburg       1.0

# %% [markdown]
# # 3. Filtre dupa conditie

# %%
df[df["trophies"] > 2]
# Out:
#     country        team  trophies
# id
# 0   England   Liverpool       6.0
# 1     Spain   Barcelona       5.0
# 2   England  Man United       3.0
# 3     Italy       Inter       3.0

# %%
conditie1 = df["trophies"] > 1
conditie2 = df["trophies"] < 5


df[ conditie1 & conditie2] # & - SI Logic
# Out:
#      country          team  trophies
# id
# 2    England    Man United       3.0
# 3      Italy         Inter       3.0
# 4    England       Chelsea       2.0
# 5    England       Chelsea       2.0
# 6    England  Nottm Forest       2.0
# 7   Portugal       Benfica       2.0
# 8      Italy      Juventus       2.0
# 9   Portugal      FC Porto       2.0

# %%
conditie1 = df["trophies"] < 2
conditie2 = df["trophies"] > 5


df[ conditie1 | conditie2] # & - SAU Logic
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool       6.0
# 10      England       Man City       1.0
# 11      Germany       Dortmund       1.0
# 12  Netherlands      Feyenoord       1.0
# 13       France      Marseille       1.0
# 14      England    Aston Villa       1.0
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %%
df.keys()
# Out:
# Index(['country', 'team', 'trophies'], dtype='object')

# %%
df[['team', 'trophies','country' ]] # creaza un nou dataframe
# Out:
#              team  trophies      country
# id
# 0       Liverpool       6.0      England
# 1       Barcelona       5.0        Spain
# 2      Man United       3.0      England
# 3           Inter       3.0        Italy
# 4         Chelsea       2.0      England
# 5         Chelsea       2.0      England
# 6    Nottm Forest       2.0      England
# 7         Benfica       2.0     Portugal
# 8        Juventus       2.0        Italy
# 9        FC Porto       2.0     Portugal
# 10       Man City       1.0      England
# 11       Dortmund       1.0      Germany
# 12      Feyenoord       1.0  Netherlands
# 13      Marseille       1.0       France
# 14    Aston Villa       1.0      England
# 15        Hamburg       1.0      Germany
# 16  Crvena zvezda       1.0       Serbia
# 17           FCSB       NaN      Romania
# 18            PSV       1.0  Netherlands
# 19         Celtic       1.0     Scotland

# %%
df
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool       6.0
# 1         Spain      Barcelona       5.0
# 2       England     Man United       3.0
# 3         Italy          Inter       3.0
# 4       England        Chelsea       2.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      England       Man City       1.0
# 11      Germany       Dortmund       1.0
# 12  Netherlands      Feyenoord       1.0
# 13       France      Marseille       1.0
# 14      England    Aston Villa       1.0
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %% [markdown]
# # 4. Gasirea valorilor lipsa

# %%
df.isnull().sum()
# Out:
# country     0
# team        0
# trophies    1
# dtype: int64

# %%
df [df.isnull().any(axis=1)]
# Out:
#     country  team  trophies
# id
# 17  Romania  FCSB       NaN

# %% [markdown]
# # 5. Creare de coloane noi

# %%
df.head(2)
# Out:
#     country       team  trophies
# id
# 0   England  Liverpool       6.0
# 1     Spain  Barcelona       5.0

# %%
df["Big Team"] = df["trophies"] > 2
df
# Out:
#         country           team  trophies  Big Team
# id
# 0       England      Liverpool       6.0      True
# 1         Spain      Barcelona       5.0      True
# 2       England     Man United       3.0      True
# 3         Italy          Inter       3.0      True
# 4       England        Chelsea       2.0     False
# 5       England        Chelsea       2.0     False
# 6       England   Nottm Forest       2.0     False
# 7      Portugal        Benfica       2.0     False
# 8         Italy       Juventus       2.0     False
# 9      Portugal       FC Porto       2.0     False
# 10      England       Man City       1.0     False
# 11      Germany       Dortmund       1.0     False
# 12  Netherlands      Feyenoord       1.0     False
# 13       France      Marseille       1.0     False
# 14      England    Aston Villa       1.0     False
# 15      Germany        Hamburg       1.0     False
# 16       Serbia  Crvena zvezda       1.0     False
# ...

# %% [markdown]
# # De la bool catre toate celelalte tipuri de date de baza

# %%
x = True
type(x)
# Out:
# bool

# %%
x = True
int(x)
# Out:
# 1

# %%
x = True
float(x)
# Out:
# 1.0

# %%
x = True
str(x)
# Out:
# 'True'

# %% [markdown]
# # De la int catre celelalte

# %%
x = 23
bool(x)
# Out:
# True

# %%
x = 0
bool(x)
# Out:
# False

# %%
x = -2323
bool(x)
# Out:
# True

# %%
x = 23
float(x)
# Out:
# 23.0

# %%
x = 23
str(x)
# Out:
# '23'

# %% [markdown]
# # De la float catre celalte

# %%
x = 23.32
bool(x)
# Out:
# True

# %%
x = 0.0
bool(x)
# Out:
# False

# %%
x = -0.032
bool(x)
# Out:
# True

# %%
x = 23.32
int(x)
# Out:
# 23

# %%
x = 23.32
str(x)
# Out:
# '23.32'

# %% [markdown]
# # De la string catre celelalte

# %%
x = '120'
int(x)
# Out:
# 120

# %%
x = '120'
float(x)
# Out:
# 120.0

# %%
x = '120.32'
float(x)
# Out:
# 120.32

# %%
x = '120.32'
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 x = '120.32'
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: '120.32'

# %%
x = '120.32'
int(float(x))
# Out:
# 120

# %%
x = '120.32'
bool(x)
# Out:
# True

# %%
x = ' '
bool(x)
# Out:
# True

# %%
x = ''
bool(x)
# Out:
# False

# %%
x = ""
bool(x)
# Out:
# False

# %%
x = '0'
bool(x)
# Out:
# True

# %%
x = 'cafea'
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 x = 'cafea'
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: 'cafea'

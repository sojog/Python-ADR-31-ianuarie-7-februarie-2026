# %%
print(10)
# Out:
# 10

# %%
print(10, 20, 30)
# Out:
# 10 20 30

# %%
print(10, 20, 30, 30, 40, 20, 300, 30)
# Out:
# 10 20 30 30 40 20 300 30

# %%
print(10, 20, 30, 30, 40, 20, 300, 30, sep="???")
# Out:
# 10???20???30???30???40???20???300???30

# %%
print(10, 20, 30, 30, 40, 20, 300, 30, sep="__")
print(10, 20, 30, 30, 40, 20, 300, 30, sep="--")
# Out:
# 10__20__30__30__40__20__300__30
# 10--20--30--30--40--20--300--30

# %%
print(10, 20, 30, 30, 40, 20, 300, 30, sep="__", end='>>>>>>')
print(10, 20, 30, 30, 40, 20, 300, 30, sep="--")
# Out:
# 10__20__30__30__40__20__300__30>>>>>>10--20--30--30--40--20--300--30

# %%
print()

# %%
print(23)
# Out:
# 23
